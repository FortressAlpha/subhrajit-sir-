# %% [markdown]
# <a href="https://colab.research.google.com/github/FortressAlpha/subhrajit-sir-/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data = np.array([
    [1, 1.2],
    [1, 1.4],
    [5, 6],
    [5.5, 7.5],
    [9.5, 0.5],
    [10, 0.8],
    [1.5, 1.8],
    [6, 8],
    [5.8, 6.5],
    [0.7, 1.5],
    [9, 1]
])

# %%
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
labels = kmeans.fit_predict(data)
centroids = kmeans.cluster_centers_

plt.figure(figsize=(7,6))
plt.scatter(data[:,0], data[:,1], c=labels, cmap='viridis', s=100)
plt.scatter(centroids[:,0], centroids[:,1], c='red', marker='X', s=250)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("K-Means Clustering (k = 3)")
plt.grid(True)
plt.show()
